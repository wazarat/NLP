# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the news api to pull the latest news articles for bitcoin and ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer() 
from newsapi import NewsApiClient
# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\wazar\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Read your api key environment variable
load_dotenv()
api_key = os.getenv("NEWS_API_KEY")

# %%
# Create a newsapi client
newsapi = NewsApiClient(api_key=api_key)

# %%
# Fetch the Bitcoin news articles
bitcoin_news = newsapi.get_everything(
    q='bitcoin',
    language="en",
    sort_by="relevancy"
)
#bitcoin_news = newsapi.get_everything(q="Bitcoin", language="en")

bitcoin_news["totalResults"]
# Out:
# 5463

# %%
# Fetch the Ethereum news articles
ethereum_news = newsapi.get_everything(q="Ethereum", language="en")
ethereum_news["totalResults"]
# Out:
# 1340

# %%
# Create the Bitcoin sentiment scores DataFrame
def df_maker(news, language):
    articles = []
    for article in news:
        try:
            sentiment = analyzer.polarity_scores(article["description"])
            title = article["title"]
            description = article["description"]
            text = article["content"]
            date = article["publishedAt"][:10]
            
            articles.append({
                "Title": title,
                "Description": description,
                "Text": text,
                "Date": date,
                "Compound": sentiment["compound"],
                "Positive": sentiment["pos"],
                "Negative": sentiment["neg"],
                "Neutral": sentiment["neu"],
            })
            
            cols = ["Compound", "Negative", "Neutral", "Positive", "Text"]
        except AttributeError:
            pass
    
    return pd.DataFrame(articles)[cols]

bitcoin_df = df_maker(bitcoin_news["articles"],"en")
bitcoin_df.head()
# Out:
#    Compound  Negative  Neutral  Positive  \
# 0    0.7506     0.000    0.811     0.189
# 1    0.4019     0.000    0.930     0.070
# 2    0.3400     0.000    0.876     0.124
# 3    0.0813     0.048    0.897     0.055
# 4    0.3612     0.074    0.767     0.158
#
#                                                 Text
# 0  After reaching a previous all-time high on Nov...
# 1  Its been almost three years to the day since t...
# 2  Everything is dumb until it works.\r\nAs 2020 ...
# 3  The government of India is considering an 18% ...
# 4  Just weeks after it shattered its yearslong as...

# %%
# Create the Ethereum sentiment scores DataFrame
ethereum_df = df_maker(ethereum_news["articles"],"en")

ethereum_df.head()
# Out:
#    Compound  Negative  Neutral  Positive  \
# 0    0.5267     0.000    0.888     0.112
# 1    0.0772     0.071    0.874     0.055
# 2    0.0788     0.051    0.891     0.058
# 3   -0.4019     0.083    0.917     0.000
# 4   -0.4019     0.083    0.917     0.000
#
#                                                 Text
# 0  The Securities and Exchange Commission plans t...
# 1  Bitcoin was once derided by serious investors ...
# 2  Cryptocurrencies stole headlines on the first ...
# 3  FILE PHOTO: A representation of virtual curren...
# 4  FILE PHOTO: Representations of virtual currenc...

# %%
# Describe the Bitcoin Sentiment
bitcoin_df.describe()
# Out:
#         Compound   Negative    Neutral   Positive
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.221585   0.027450   0.876900   0.095550
# std     0.323745   0.046389   0.081369   0.072699
# min    -0.585900   0.000000   0.746000   0.000000
# 25%     0.000000   0.000000   0.807500   0.041250
# 50%     0.340000   0.000000   0.886000   0.106500
# 75%     0.406800   0.051750   0.937500   0.150500
# max     0.750600   0.124000   1.000000   0.211000

# %%
# Describe the Ethereum Sentiment
ethereum_df.describe()
# Out:
#         Compound   Negative    Neutral  Positive
# count  20.000000  20.000000  20.000000  20.00000
# mean    0.037055   0.037450   0.911200   0.05135
# std     0.338136   0.047129   0.066676   0.06145
# min    -0.401900   0.000000   0.769000   0.00000
# 25%    -0.318200   0.000000   0.876250   0.00000
# 50%     0.000000   0.000000   0.917000   0.04200
# 75%     0.218425   0.074750   0.958000   0.07300
# max     0.636900   0.162000   1.000000   0.19700

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A:
#
# Q: Which coin had the highest compound score?
#
# A:
#
# Q. Which coin had the highest positive score?
#
# A:

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Natural Language Processing
# ---
# ###   Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word
# 2. Remove Punctuation
# 3. Remove Stopwords

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Expand the default stopwords list if necessary
#not needed

# %%
# Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
    
    # Create a list of the words

    # Convert the words to lowercase
    
    # Remove the punctuation
    
    # Remove the stop words
    
    # Lemmatize Words into root words
def tokenizer(text):
    sw = set(stopwords.words('english'))
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('', text)
    words = word_tokenize(re_clean)
    lem = [lemmatizer.lemmatize(word) for word in words]
    tokens = [word.lower() for word in lem if word.lower() not in sw]
    return tokens

# %%
# Create a new tokens column for Bitcoin
bitcoin_df['Text'] = str(bitcoin_df['Text'])
btc_tokens = []
for i in bitcoin_df['Text']:
    tokenized_text = tokenizer(i)
    btc_tokens.append({'tokens':tokenized_text})

btc_tokens_df = pd.DataFrame(btc_tokens)
bitcoin_df['tokens'] = btc_tokens_df
bitcoin_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-f347d3f14f5a> in <module>
#       3 btc_tokens = []
#       4 for i in bitcoin_df['Text']:
# ----> 5     tokenized_text = tokenizer(i)
#       6     btc_tokens.append({'tokens':tokenized_text})
#       7
#
# <ipython-input-32-fbe5a9218ae6> in tokenizer(text)
#      17     re_clean = regex.sub('', text)
#      18     words = word_tokenize(re_clean)
# ---> 19     lem = [lemmatizer.lemmatize(word) for word in words]
#      20     tokens = [word.lower() for word in lem if word.lower() not in sw]
#      21     return tokens
#
# <ipython-input-32-fbe5a9218ae6> in <listcomp>(.0)
#      17     re_clean = regex.sub('', text)
#      18     words = word_tokenize(re_clean)
# ---> 19     lem = [lemmatizer.lemmatize(word) for word in words]
#      20     tokens = [word.lower() for word in lem if word.lower() not in sw]
#      21     return tokens
#
# NameError: name 'lemmatizer' is not defined

# %%
# Create a new tokens column for Ethereum
ethereum_df['Text'] = str(ethereum_df['Text'])

eth_tokens = []
for i in ethereum_df['Text']:
    tokenized_text = tokenizer(i)
    eth_tokens.append({'tokens':tokenized_text})

eth_tokens_df = pd.DataFrame(eth_tokens)
ethereum_df['tokens'] = eth_tokens_df
ethereum_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-1c6923d9b498> in <module>
#       4 eth_tokens = []
#       5 for i in ethereum_df['Text']:
# ----> 6     tokenized_text = tokenizer(i)
#       7     eth_tokens.append({'tokens':tokenized_text})
#       8
#
# <ipython-input-32-fbe5a9218ae6> in tokenizer(text)
#      17     re_clean = regex.sub('', text)
#      18     words = word_tokenize(re_clean)
# ---> 19     lem = [lemmatizer.lemmatize(word) for word in words]
#      20     tokens = [word.lower() for word in lem if word.lower() not in sw]
#      21     return tokens
#
# <ipython-input-32-fbe5a9218ae6> in <listcomp>(.0)
#      17     re_clean = regex.sub('', text)
#      18     words = word_tokenize(re_clean)
# ---> 19     lem = [lemmatizer.lemmatize(word) for word in words]
#      20     tokens = [word.lower() for word in lem if word.lower() not in sw]
#      21     return tokens
#
# NameError: name 'lemmatizer' is not defined

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
def process_text(doc):
    sw = set(stopwords.words('english'))
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('', doc)
    words = word_tokenize(re_clean)
    lemmatizer = WordNetLemmatizer()
    lem = [lemmatizer.lemmatize(word) for word in words]
    output = [word.lower() for word in lem if word.lower() not in sw]
    return output

def bigram_counter(corpus): 
    big_string = " ".join(corpus)
    processed = process_text(big_string)
    bigrams = ngrams(processed, n=2)
    top_15 = dict(Counter(bigrams).most_common(15))
    return pd.DataFrame(list(top_15.items()), columns=['word','count'])

# Generate the Bitcoin N-grams where N=2
corpus = bitcoin_df["Text"]
bigram_counter(corpus)
# Out:
#                         word  count
# 0     (reuters, staffrnfile)     40
# 1       (staffrnfile, photo)     40
# 2   (reuters, staffrnlondon)     40
# 3       (reaching, previous)     20
# 4        (previous, alltime)     20
# 5            (alltime, high)     20
# 6                (high, nov)     20
# 7              (nov, almost)     20
# 8            (almost, three)     20
# 9              (three, year)     20
# 10               (year, day)     20
# 11              (day, since)     20
# 12       (since, everything)     20
# 13        (everything, dumb)     20
# 14         (dumb, worksrnas)     20

# %%
# Generate the Ethereum N-grams where N=2
corpus = ethereum_df["Text"]
bigram_counter(corpus)
# Out:
#                           word  count
# 0                (file, photo)     80
# 1                  (new, york)     80
# 2              (york, reuters)     80
# 3      (photo, representation)     40
# 4    (representation, virtual)     40
# 5            (virtual, curren)     40
# 6     (photo, representations)     40
# 7   (representations, virtual)     40
# 8           (virtual, currenc)     40
# 9     (reuters, institutional)     40
# 10   (institutional, investor)     40
# 11               (investor, p)     40
# 12                    (p, new)     40
# 13      (securities, exchange)     20
# 14      (exchange, commission)     20

# %%
# Use the token_count function to generate the top 10 words from each coin
def token_count(tokens, N=3):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
btc_words = []
for text in bitcoin_df['tokens']:
    for word in text:
        btc_words.append(word)
        
token_count(btc_words)# Get the top 10 words for Bitcoin
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'tokens'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-e4d341f5e415> in <module>
#       1 btc_words = []
# ----> 2 for text in bitcoin_df['tokens']:
#       3     for word in text:
#       4         btc_words.append(word)
#       5
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'tokens'

# %%
# Get the top 10 words for Ethereum
eth_words = []
for text in ethereum_df['tokens']:
    for word in text:
        eth_words.append(word)
        
token_count(eth_words)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'tokens'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-d880a54e69fd> in <module>
#       1 # Get the top 10 words for Ethereum
#       2 eth_words = []
# ----> 3 for text in ethereum_df['tokens']:
#       4     for word in text:
#       5         eth_words.append(word)
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'tokens'

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-41-0a1ecd929acc> in <module>
# ----> 1 from wordcloud import WordCloud
#       2 import matplotlib.pyplot as plt
#       3 plt.style.use('seaborn-whitegrid')
#       4 import matplotlib as mpl
#       5 mpl.rcParams['figure.figsize'] = [20.0, 10.0]
#
# ModuleNotFoundError: No module named 'wordcloud'

# %%
# Generate the Bitcoin word cloud
def stringmaker(words):
    big_string = " ".join(words)
    return big_string

btc_words = stringmaker(btc_words)
eth_words = stringmaker(eth_words)

btc_word_cloud = WordCloud(width=1200, height=800, max_words=30).generate(btc_words)

plt.imshow(btc_word_cloud)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-029933101ec4> in <module>
#       7 eth_words = stringmaker(eth_words)
#       8
# ----> 9 btc_word_cloud = WordCloud(width=1200, height=800, max_words=30).generate(btc_words)
#      10
#      11 plt.imshow(btc_word_cloud)
#
# NameError: name 'WordCloud' is not defined

# %%
# Generate the Ethereum word cloud
eth_word_cloud = WordCloud(width=1200, height=800, max_words=30).generate(eth_words)

plt.imshow(eth_word_cloud)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-236218af23c1> in <module>
#       1 # Generate the Ethereum word cloud
# ----> 2 eth_word_cloud = WordCloud(width=1200, height=800, max_words=30).generate(eth_words)
#       3
#       4 plt.imshow(eth_word_cloud)
#
# NameError: name 'WordCloud' is not defined

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Optional - download a language model for SpaCy
# !python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: en_core_web_sm==2.3.1 from https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.3.1/en_core_web_sm-2.3.1.tar.gz#egg=en_core_web_sm==2.3.1 in c:\users\wazar\anaconda3\envs\pyvizenv\lib\site-packages (2.3.1)
# Requirement already satisfied: spacy<2.4.0,>=2.3.0 in c:\users\wazar\anaconda3\envs\pyvizenv\lib\site-packages (from en_core_web_sm==2.3.1) (2.3.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in c:\users\wazar\anaconda3\envs\pyvizenv\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (0.8.0)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\wazar\anaconda3\envs\pyvizenv\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.19.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\wazar\anaconda3\envs\pyvizenv\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (4.47.0)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\wazar\anaconda3\envs\pyvizenv\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (0.7.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\wazar\anaconda3\envs\pyvizenv\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.0.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\wazar\anaconda3\envs\pyvizenv\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (3.0.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\wazar\anaconda3\envs\pyvizenv\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (2.0.5)
# Requirement already satisfied: thinc<7.5.0,>=7.4.1 in c:\users\wazar\anaconda3\envs\pyvizenv\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (7.4.5)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in c:\users\wazar\anaconda3\envs\pyvizenv\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.1.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\wazar\anaconda3\envs\pyvizenv\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (2.24.0)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in c:\users\wazar\anaconda3\envs\pyvizenv\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.0.0)
# Requirement already satisfied: setuptools in c:\users\wazar\anaconda3\envs\pyvizenv\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (49.2.0.post20200714)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in c:\users\wazar\anaconda3\envs\pyvizenv\lib\site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.0.5)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\wazar\anaconda3\envs\pyvizenv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\wazar\anaconda3\envs\pyvizenv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.25.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\wazar\anaconda3\envs\pyvizenv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\wazar\anaconda3\envs\pyvizenv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (2020.6.20)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in c:\users\wazar\anaconda3\envs\pyvizenv\lib\site-packages (from catalogue<1.1.0,>=0.0.7->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.7.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\wazar\anaconda3\envs\pyvizenv\lib\site-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (3.1.0)
# [+] Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ---
# ### Bitcoin NER

# %%
articles = bitcoin_df["Text"].str.cat()
articles

# Run the NER processor on all of the text
# YOUR CODE HERE!
doc = nlp(articles)

# Add a title to the document
# YOUR CODE HERE!
doc.user_data['title'] = 'Bitcoin NER'

# %%
# Render the visualization
displacy.render(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Bitcoin NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">0     After reaching a previous all-time high on Nov...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#      Its been almost three years to the day since t...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#      Everything is dumb until it works.\r\nAs 2020 ...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#      The government of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  is considering an
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     18%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  ...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#      Just weeks after it shattered its yearslong as...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     New York
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CNN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Business)Bitcoin has been flirti...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     6
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Securities and Exchange Commission
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  plans t...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     7
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#      Unlike ‘conventional’ cryptocurrencies,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     a cent
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# ...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#      image copyrightGetty Images\r\nBitcoin has hit...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     9
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
# Six years after the launch of the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mexico
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# -based...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#                                                  None</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     11
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#     Illustration by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Grayson Blackmon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  / The Verge\r...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     12
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     6
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  with
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     6
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# <

# %%
# List all Entities
for ent in doc.ents:
    print (ent, ent.label_)
# Out:
# 1 CARDINAL
# 2 CARDINAL
# 3 CARDINAL
# India GPE
# 18% PERCENT
# 4 CARDINAL
# 5 CARDINAL
# New York GPE
# CNN ORG
# 6 CARDINAL
# The Securities and Exchange Commission ORG
# 7 CARDINAL
# a cent MONEY
# 8 CARDINAL
# 9      QUANTITY
# Mexico GPE
# 10 CARDINAL
# 11 CARDINAL
# Grayson Blackmon PERSON
# 12 CARDINAL
# 6 CARDINAL
# 6 CARDINAL
# participating\r\nThe NORP
# 13 CARDINAL
# Bitcoin GPE
# 14 CARDINAL
# 15 CARDINAL
# 16 CARDINAL
# 17 CARDINAL
# Reuters Staff\r\nLONDON ORG
# Dec 30 DATE
# Reuters ORG
# 18 CARDINAL
# 19 CARDINAL
# Reuters Staff\r\nLONDON ORG
# Jan 4 DATE
# Reuters ORG
# 1 CARDINAL
# 2 CARDINAL
# 3 CARDINAL
# India GPE
# 18% PERCENT
# 4 CARDINAL
# 5 CARDINAL
# New York GPE
# CNN ORG
# 6 CARDINAL
# The Securities and Exchange Commission ORG
# 7 CARDINAL
# a cent MONEY
# 8 CARDINAL
# 9      QUANTITY
# Mexico GPE
# 10 CARDINAL
# 11 CARDINAL
# Grayson Blackmon PERSON
# 12 CARDINAL
# 6 CARDINAL
# 6 CARDINAL
# participating\r\nThe NORP
# 13 CARDINAL
# Bitcoin GPE
# 14 CARDINAL
# 15 CARDINAL
# 16 CARDINAL
# 17 CARDINAL
# Reuters Staff\r\nLONDON ORG
# Dec 30 DATE
# Reuters ORG
# 18 CARDINAL
# 19 CARDINAL
# Reuters Staff\r\nLONDON ORG
# Jan 4 DATE
# Reuters ORG
# 1 CARDINAL
# 2 CARDINAL
# 3 CARDINAL
# India GPE
# 18% PERCENT
# 4 CARDINAL
# 5 CARDINAL
# New York GPE
# CNN ORG
# 6 CARDINAL
# The Securities and Exchange Commission ORG
# 7 CARDINAL
# a cent MONEY
# 8 CARDINAL
# 9      QUANTITY
# Mexico GPE
# 10 CARDINAL
# 11 CARDINAL
# Grayson Blackmon PERSON
# 12 CARDINAL
# 6 CARDINAL
# 6 CARDINAL
# participating\r\nThe NORP
# 13 CARDINAL
# Bitcoin GPE
# 14 CARDINAL
# 15 CARDINAL
# 16 CARDINAL
# 17 CARDINAL
# Reuters Staff\r\nLONDON ORG
# Dec 30 DATE
# Reuters ORG
# 18 CARDINAL
# 19 CARDINAL
# Reuters Staff\r\nLONDON ORG
# Jan 4 DATE
# Reuters ORG
# 1 CARDINAL
# 2 CARDINAL
# 3 CARDINAL
# India GPE
# 18% PERCENT
# 4 CARDINAL
# 5 CARDINAL
# New York GPE
# CNN ORG
# 6 CARDINAL
# The Securities and Exchange Commission ORG
# 7 CARDINAL
# a cent MONEY
# 8 CARDINAL
# 9      QUANTITY
# Mexico GPE
# 10 CARDINAL
# 11 CARDINAL
# Grayson Blackmon PERSON
# 12 CARDINAL
# 6 CARDINAL
# 6 CARDINAL
# participating\r\nThe NORP
# 13 CARDINAL
# Bitcoin GPE
# 14 CARDINAL
# 15 CARDINAL
# 16 CARDINAL
# 17 CARDINAL
# Reuters Staff\r\nLONDON ORG
# Dec 30 DATE
# Reuters ORG
# 18 CARDINAL
# 19 CARDINAL
# Reuters Staff\r\nLONDON ORG
# Jan 4 DATE
# Reuters ORG
# 1 CARDINAL
# 2 CARDINAL
# 3 CARDINAL
# India GPE
# 18% PERCENT
# 4 CARDINAL
# 5 CARDINAL
# New York GPE
# CNN ORG
# 6 CARDINAL
# The Securities and Exchange Commission ORG
# 7 CARDINAL
# a cent MONEY
# 8 CARDINAL
# 9      QUANTITY
# Mexico GPE
# 10 CARDINAL
# 11 CARDINAL
# Grayson Blackmon PERSON
# 12 CARDINAL
# 6 CARDINAL
# 6 CARDINAL
# participating\r\nThe NORP
# 13 CARDINAL
# Bitcoin GPE
# 14 CARDINAL
# 15 CARDINAL
# 16 CARDINAL
# 17 CARDINAL
# Reuters Staff\r\nLONDON ORG
# Dec 30 DATE
# Reuters ORG
# 18 CARDINAL
# 19 CARDINAL
# Reuters Staff\r\nLONDON ORG
# Jan 4 DATE
# Reuters ORG
# 1 CARDINAL
# 2 CARDINAL
# 3 CARDINAL
# India GPE
# 18% PERCENT
# 4 CARDINAL
# 5 CARDINAL
# New York GPE
# CNN ORG
# 6 CARDINAL
# The Securities and Exchange Commission ORG
# 7 CARDINAL
# a cent MONEY
# 8 CARDINAL
# 9      QUANTITY
# Mexico GPE
# 10 CARDINAL
# 11 CARDINAL
# Grayson Blackmon PERSON
# 12 CARDINAL
# 6 CARDINAL
# 6 CARDINAL
# participating\r\nThe NORP
# 13 CARDINAL
# Bitcoin GPE
# 14 CARDINAL
# 15 CARDINAL
# 16 CARDINAL
# 17 CARDINAL
# Reuters Staff\r\nLONDON ORG
# Dec 30 DATE
# Reuters ORG
# 18 CARDINAL
# 19 CARDINAL
# Reuters Staff\r\nLONDON ORG
# Jan 4 DATE
# Reuters ORG
# 1 CARDINAL
# 2 CARDINAL
# 3 CARDINAL
# India GPE
# 18% PERCENT
# 4 CARDINAL
# 5 CARDINAL
# New York GPE
# CNN ORG
# 6 CARDINAL
# The Securities and Exchange Commission ORG
# 7 CARDINAL
# a cent MONEY
# 8 CARDINAL
# 9      QUANTITY
# Mexico GPE
# 10 CARDINAL
# 11 CARDINAL
# Grayson Blackmon PERSON
# 12 CARDINAL
# 6 CARDINAL
# 6 CARDINAL
# participating\r\nThe NORP
# 13 CARDINAL
# Bitcoin GPE
# 14 CARDINAL
# 15 CARDINAL
# 16 CARDINAL
# 17 CARDINAL
# Reuters Staff\r\nLONDON ORG
# Dec 30 DATE
# Reuters ORG
# 18 CARDINAL
# 19 CARDINAL
# Reuters Staff\r\nLONDON ORG
# Jan 4 DATE
# Reuters ORG
# 1 CARDINAL
# 2 CARDINAL
# 3 CARDINAL
# India GPE
# 18% PERCENT
# 4 CARDINAL
# 5 CARDINAL
# New York GPE
# CNN ORG
# 6 CARDINAL
# The Securities and Exchange Commission ORG
# 7 CARDINAL
# a cent MONEY
# 8 CARDINAL
# 9      QUANTITY
# Mexico GPE
# 10 CARDINAL
# 11 CARDINAL
# Grayson Blackmon PERSON
# 12 CARDINAL
# 6 CARDINAL
# 6 CARDINAL
# participating\r\nThe NORP
# 13 CARDINAL
# Bitcoin GPE
# 14 CARDINAL
# 15 CARDINAL
# 16 CARDINAL
# 17 CARDINAL
# Reuters Staff\r\nLONDON ORG
# Dec 30 DATE
# Reuters ORG
# 18 CARDINAL
# 19 CARDINAL
# Reuters Staff\r\nLONDON ORG
# Jan 4 DATE
# Reuters ORG
# 1 CARDINAL
# 2 CARDINAL
# 3 CARDINAL
# India GPE
# 18% PERCENT
# 4 CARDINAL
# 5 CARDINAL
# New York GPE
# CNN ORG
# 6 CARDINAL
# The Securities and Exchange Commission ORG
# 7 CARDINAL
# a cent MONEY
# 8 CARDINAL
# 9      QUANTITY
# Mexico GPE
# 10 CARDINAL
# 11 CARDINAL
# Grayson Blackmon PERSON
# 12 CARDINAL
# 6 CARDINAL
# 6 CARDINAL
# participating\r\nThe NORP
# 13 CARDINAL
# Bitcoin GPE
# 14 CARDINAL
# 15 CARDINAL
# 16 CARDINAL
# 17 CARDINAL
# Reuters Staff\r\nLONDON ORG
# Dec 30 DATE
# Reuters ORG
# 18 CARDINAL
# 19 CARDINAL
# Reuters Staff\r\nLONDON ORG
# Jan 4 DATE
# Reuters ORG
# 1 CARDINAL
# 2 CARDINAL
# 3 CARDINAL
# India GPE
# 18% PERCENT
# 4 CARDINAL
# 5 CARDINAL
# New York GPE
# CNN ORG
# 6 CARDINAL
# The Securities and Exchange Commission ORG
# 7 CARDINAL
# a cent MONEY
# 8 CARDINAL
# 9      QUANTITY
# Mexico GPE
# 10 CARDINAL
# 11 CARDINAL
# Grayson Blackmon PERSON
# 12 CARDINAL
# 6 CARDINAL
# 6 CARDINAL
# participating\r\nThe NORP
# 13 CARDINAL
# Bitcoin GPE
# 14 CARDINAL
# 15 CARDINAL
# 16 CARDINAL
# 17 CARDINAL
# Reuters Staff\r\nLONDON ORG
# Dec 30 DATE
# Reuters ORG
# 18 CARDINAL
# 19 CARDINAL
# Reuters Staff\r\nLONDON ORG
# Jan 4 DATE
# Reuters ORG
# 1 CARDINAL
# 2 CARDINAL
# 3 CARDINAL
# India GPE
# 18% PERCENT
# 4 CARDINAL
# 5 CARDINAL
# New York GPE
# CNN ORG
# 6 CARDINAL
# The Securities and Exchange Commission ORG
# 7 CARDINAL
# a cent MONEY
# 8 CARDINAL
# 9      QUANTITY
# Mexico GPE
# 10 CARDINAL
# 11 CARDINAL
# Grayson Blackmon PERSON
# 12 CARDINAL
# 6 CARDINAL
# 6 CARDINAL
# participating\r\nThe NORP
# 13 CARDINAL
# Bitcoin GPE
# 14 CARDINAL
# 15 CARDINAL
# 16 CARDINAL
# 17 CARDINAL
# Reuters Staff\r\nLONDON ORG
# Dec 30 DATE
# Reuters ORG
# 18 CARDINAL
# 19 CARDINAL
# Reuters Staff\r\nLONDON ORG
# Jan 4 DATE
# Reuters ORG
# 1 CARDINAL
# 2 CARDINAL
# 3 CARDINAL
# India GPE
# 18% PERCENT
# 4 CARDINAL
# 5 CARDINAL
# New York GPE
# CNN ORG
# 6 CARDINAL
# The Securities and Exchange Commission ORG
# 7 CARDINAL
# a cent MONEY
# 8 CARDINAL
# 9      QUANTITY
# Mexico GPE
# 10 CARDINAL
# 11 CARDINAL
# Grayson Blackmon PERSON
# 12 CARDINAL
# 6 CARDINAL
# 6 CARDINAL
# participating\r\nThe NORP
# 13 CARDINAL
# Bitcoin GPE
# 14 CARDINAL
# 15 CARDINAL
# 16 CARDINAL
# 17 CARDINAL
# Reuters Staff\r\nLONDON ORG
# Dec 30 DATE
# Reuters ORG
# 18 CARDINAL
# 19 CARDINAL
# Reuters Staff\r\nLONDON ORG
# Jan 4 DATE
# Reuters ORG
# 1 CARDINAL
# 2 CARDINAL
# 3 CARDINAL
# India GPE
# 18% PERCENT
# 4 CARDINAL
# 5 CARDINAL
# New York GPE
# CNN ORG
# 6 CARDINAL
# The Securities and Exchange Commission ORG
# 7 CARDINAL
# a cent MONEY
# 8 CARDINAL
# 9      QUANTITY
# Mexico GPE
# 10 CARDINAL
# 11 CARDINAL
# Grayson Blackmon PERSON
# 12 CARDINAL
# 6 CARDINAL
# 6 CARDINAL
# participating\r\nThe NORP
# 13 CARDINAL
# Bitcoin GPE
# 14 CARDINAL
# 15 CARDINAL
# 16 CARDINAL
# 17 CARDINAL
# Reuters Staff\r\nLONDON ORG
# Dec 30 DATE
# Reuters ORG
# 18 CARDINAL
# 19 CARDINAL
# Reuters Staff\r\nLONDON ORG
# Jan 4 DATE
# Reuters ORG
# 1 CARDINAL
# 2 CARDINAL
# 3 CARDINAL
# India GPE
# 18% PERCENT
# 4 CARDINAL
# 5 CARDINAL
# New York GPE
# CNN ORG
# 6 CARDINAL
# The Securities and Exchange Commission ORG
# 7 CARDINAL
# a cent MONEY
# 8 CARDINAL
# 9      QUANTITY
# Mexico GPE
# 10 CARDINAL
# 11 CARDINAL
# Grayson Blackmon PERSON
# 12 CARDINAL
# 6 CARDINAL
# 6 CARDINAL
# participating\r\nThe NORP
# 13 CARDINAL
# Bitcoin GPE
# 14 CARDINAL
# 15 CARDINAL
# 16 CARDINAL
# 17 CARDINAL
# Reuters Staff\r\nLONDON ORG
# Dec 30 DATE
# Reuters ORG
# 18 CARDINAL
# 19 CARDINAL
# Reuters Staff\r\nLONDON ORG
# Jan 4 DATE
# Reuters ORG
# 1 CARDINAL
# 2 CARDINAL
# 3 CARDINAL
# India GPE
# 18% PERCENT
# 4 CARDINAL
# 5 CARDINAL
# New York GPE
# CNN ORG
# 6 CARDINAL
# The Securities and Exchange Commission ORG
# 7 CARDINAL
# a cent MONEY
# 8 CARDINAL
# 9      QUANTITY
# Mexico GPE
# 10 CARDINAL
# 11 CARDINAL
# Grayson Blackmon PERSON
# 12 CARDINAL
# 6 CARDINAL
# 6 CARDINAL
# participating\r\nThe NORP
# 13 CARDINAL
# Bitcoin GPE
# 14 CARDINAL
# 15 CARDINAL
# 16 CARDINAL
# 17 CARDINAL
# Reuters Staff\r\nLONDON ORG
# Dec 30 DATE
# Reuters ORG
# 18 CARDINAL
# 19 CARDINAL
# Reuters Staff\r\nLONDON ORG
# Jan 4 DATE
# Reuters ORG
# 1 CARDINAL
# 2 CARDINAL
# 3 CARDINAL
# India GPE
# 18% PERCENT
# 4 CARDINAL
# 5 CARDINAL
# New York GPE
# CNN ORG
# 6 CARDINAL
# The Securities and Exchange Commission ORG
# 7 CARDINAL
# a cent MONEY
# 8 CARDINAL
# 9      QUANTITY
# Mexico GPE
# 10 CARDINAL
# 11 CARDINAL
# Grayson Blackmon PERSON
# 12 CARDINAL
# 6 CARDINAL
# 6 CARDINAL
# participating\r\nThe NORP
# 13 CARDINAL
# Bitcoin GPE
# 14 CARDINAL
# 15 CARDINAL
# 16 CARDINAL
# 17 CARDINAL
# Reuters Staff\r\nLONDON ORG
# Dec 30 DATE
# Reuters ORG
# 18 CARDINAL
# 19 CARDINAL
# Reuters Staff\r\nLONDON ORG
# Jan 4 DATE
# Reuters ORG
# 1 CARDINAL
# 2 CARDINAL
# 3 CARDINAL
# India GPE
# 18% PERCENT
# 4 CARDINAL
# 5 CARDINAL
# New York GPE
# CNN ORG
# 6 CARDINAL
# The Securities and Exchange Commission ORG
# 7 CARDINAL
# a cent MONEY
# 8 CARDINAL
# 9      QUANTITY
# Mexico GPE
# 10 CARDINAL
# 11 CARDINAL
# Grayson Blackmon PERSON
# 12 CARDINAL
# 6 CARDINAL
# 6 CARDINAL
# participating\r\nThe NORP
# 13 CARDINAL
# Bitcoin GPE
# 14 CARDINAL
# 15 CARDINAL
# 16 CARDINAL
# 17 CARDINAL
# Reuters Staff\r\nLONDON ORG
# Dec 30 DATE
# Reuters ORG
# 18 CARDINAL
# 19 CARDINAL
# Reuters Staff\r\nLONDON ORG
# Jan 4 DATE
# Reuters ORG
# 1 CARDINAL
# 2 CARDINAL
# 3 CARDINAL
# India GPE
# 18% PERCENT
# 4 CARDINAL
# 5 CARDINAL
# New York GPE
# CNN ORG
# 6 CARDINAL
# The Securities and Exchange Commission ORG
# 7 CARDINAL
# a cent MONEY
# 8 CARDINAL
# 9      QUANTITY
# Mexico GPE
# 10 CARDINAL
# 11 CARDINAL
# Grayson Blackmon PERSON
# 12 CARDINAL
# 6 CARDINAL
# 6 CARDINAL
# participating\r\nThe NORP
# 13 CARDINAL
# Bitcoin GPE
# 14 CARDINAL
# 15 CARDINAL
# 16 CARDINAL
# 17 CARDINAL
# Reuters Staff\r\nLONDON ORG
# Dec 30 DATE
# Reuters ORG
# 18 CARDINAL
# 19 CARDINAL
# Reuters Staff\r\nLONDON ORG
# Jan 4 DATE
# Reuters ORG
# 1 CARDINAL
# 2 CARDINAL
# 3 CARDINAL
# India GPE
# 18% PERCENT
# 4 CARDINAL
# 5 CARDINAL
# New York GPE
# CNN ORG
# 6 CARDINAL
# The Securities and Exchange Commission ORG
# 7 CARDINAL
# a cent MONEY
# 8 CARDINAL
# 9      QUANTITY
# Mexico GPE
# 10 CARDINAL
# 11 CARDINAL
# Grayson Blackmon PERSON
# 12 CARDINAL
# 6 CARDINAL
# 6 CARDINAL
# participating\r\nThe NORP
# 13 CARDINAL
# Bitcoin GPE
# 14 CARDINAL
# 15 CARDINAL
# 16 CARDINAL
# 17 CARDINAL
# Reuters Staff\r\nLONDON ORG
# Dec 30 DATE
# Reuters ORG
# 18 CARDINAL
# 19 CARDINAL
# Reuters Staff\r\nLONDON ORG
# Jan 4 DATE
# Reuters ORG
# 1 CARDINAL
# 2 CARDINAL
# 3 CARDINAL
# India GPE
# 18% PERCENT
# 4 CARDINAL
# 5 CARDINAL
# New York GPE
# CNN ORG
# 6 CARDINAL
# The Securities and Exchange Commission ORG
# 7 CARDINAL
# a cent MONEY
# 8 CARDINAL
# 9      QUANTITY
# Mexico GPE
# 10 CARDINAL
# 11 CARDINAL
# Grayson Blackmon PERSON
# 12 CARDINAL
# 6 CARDINAL
# 6 CARDINAL
# participating\r\nThe NORP
# 13 CARDINAL
# Bitcoin GPE
# 14 CARDINAL
# 15 CARDINAL
# 16 CARDINAL
# 17 CARDINAL
# Reuters Staff\r\nLONDON ORG
# Dec 30 DATE
# Reuters ORG
# 18 CARDINAL
# 19 CARDINAL
# Reuters Staff\r\nLONDON ORG
# Jan 4 DATE
# Reuters ORG

# %% [markdown]
# ---

# %% [markdown]
# ### Ethereum NER

# %%
# Concatenate all of the Ethereum text together
articles = ethereum_df["Text"].str.cat()
articles
# Out:
# '0     The Securities and Exchange Commission plans t...\n1     Bitcoin was once derided by serious investors ...\n2     Cryptocurrencies stole headlines on the first ...\n3     FILE PHOTO: A representation of virtual curren...\n4     FILE PHOTO: Representations of virtual currenc...\n5     FILE PHOTO: Representations of virtual currenc...\n6     NEW YORK (Reuters) - Institutional investors p...\n7     NEW YORK (Reuters) - Institutional investors p...\n8     NEW YORK (Reuters) - Total investor inflows in...\n9     Bitcoin fizzled in Monday trading as the famou...\n10    Ethereum creator Vitalik Buterin.\\r\\n14 with 1...\n11    It seems only fitting to end 2020 on a depress...\n12    December\\r\\n15, 2020\\r\\n6 min read\\r\\nOpinions...\n13                                                 None\n14    Ethereum is one of the leading crypto projects...\n15    FILE PHOTO: A representation of virtual curren...\n16    LONDON (Reuters) - Bitcoin on Wednesday jumped...\n17    NEW YORK (Reuters) - Outsized bets on large U....\n18    Source: StackCommerce\\r\\nWhen the price of Bit...\n19    By Reuters Staff\\r\\nFILE PHOTO: Representation...\nName: Text, dtype: object0     The Securities and Exchange Commission plans t...\n1     Bitcoin was once derided by serious investors ...\n2     Cryptocurrencies stole headlines on the first ...\n3     FILE PHOTO: A representation of virtual curren...\n4     FILE PHOTO: Representations of virtual currenc...\n5     FILE PHOTO: Representations of virtual currenc...\n6     NEW YORK (Reuters) - Institutional investors p...\n7     NEW YORK (Reuters) - Institutional investors p...\n8     NEW YORK (Reuters) - Total investor inflows in...\n9     Bitcoin fizzled in Monday trading as the famou...\n10    Ethereum creator Vitalik Buterin.\\r\\n14 with 1...\n11    It seems only fitting to end 2020 on a depress...\n12    December\\r\\n15, 2020\\r\\n6 min read\\r\\nOpinions...\n13                                                 None\n14    Ethereum is one of the leading crypto projects...\n15    FILE PHOTO: A representation of virtual curren...\n16    LONDON (Reuters) - Bitcoin on Wednesday jumped...\n17    NEW YORK (Reuters) - Outsized bets on large U....\n18    Source: StackCommerce\\r\\nWhen the price of Bit...\n19    By Reuters Staff\\r\\nFILE PHOTO: Representation...\nName: Text, dtype: object0     The Securities and Exchange Commission plans t...\n1     Bitcoin was once derided by serious investors ...\n2     Cryptocurrencies stole headlines on the first ...\n3     FILE PHOTO: A representation of virtual curren...\n4     FILE PHOTO: Representations of virtual currenc...\n5     FILE PHOTO: Representations of virtual currenc...\n6     NEW YORK (Reuters) - Institutional investors p...\n7     NEW YORK (Reuters) - Institutional investors p...\n8     NEW YORK (Reuters) - Total investor inflows in...\n9     Bitcoin fizzled in Monday trading as the famou...\n10    Ethereum creator Vitalik Buterin.\\r\\n14 with 1...\n11    It seems only fitting to end 2020 on a depress...\n12    December\\r\\n15, 2020\\r\\n6 min read\\r\\nOpinions...\n13                                                 None\n14    Ethereum is one of the leading crypto projects...\n15    FILE PHOTO: A representation of virtual curren...\n16    LONDON (Reuters) - Bitcoin on Wednesday jumped...\n17    NEW YORK (Reuters) - Outsized bets on large U....\n18    Source: StackCommerce\\r\\nWhen the price of Bit...\n19    By Reuters Staff\\r\\nFILE PHOTO: Representation...\nName: Text, dtype: object0     The Securities and Exchange Commission plans t...\n1     Bitcoin was once derided by serious investors ...\n2     Cryptocurrencies stole headlines on the first ...\n3     FILE PHOTO: A representation of virtual curren...\n4     FILE PHOTO: Representations of virtual currenc...\n5     FILE PHOTO: Representations of virtual currenc...\n6     NEW YORK (Reuters) - Institutional investors p...\n7     NEW YORK (Reuters) - Institutional investors p...\n8     NEW YO ...

# %%
# Run the NER processor on all of the text
doc = nlp(articles)

# Add a title to the document
doc.user_data['title'] = 'Ethereum NER'

# %%
# Render the visualization
displacy.render(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Ethereum NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">0
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Securities and Exchange Commission
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  plans t...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  was once derided by serious investors ...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#      Cryptocurrencies stole headlines on the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  ...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#      FILE PHOTO: A representation of virtual curren...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#      FILE PHOTO: Representations of virtual currenc...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#      FILE PHOTO: Representations of virtual currenc...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     6
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#      NEW YORK (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) - Institutional investors p...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     7
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#      NEW YORK (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) - Institutional investors p...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#      NEW YORK (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) - Total investor inflows in...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     9
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  fizzled in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Monday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  trading as the famou...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#     Ethereum creator
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Vitalik Buterin.\r\n14
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  with
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# ...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     11
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#     It seems only fitting to end
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2020
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  on a depress...</br>
# <mark class="en

# %%
# List all Entities
for ent in doc.ents:
    print (ent, ent.label_)
# Out:
# The Securities and Exchange Commission ORG
# 1 CARDINAL
# Bitcoin GPE
# 2 CARDINAL
# first ORDINAL
# 3 CARDINAL
# 4 CARDINAL
# 5 CARDINAL
# 6 CARDINAL
# Reuters ORG
# 7 CARDINAL
# Reuters ORG
# 8 CARDINAL
# Reuters ORG
# 9 CARDINAL
# Bitcoin GPE
# Monday DATE
# 10 CARDINAL
# Vitalik Buterin.\r\n14 PERSON
# 1 CARDINAL
# 11 CARDINAL
# 2020 DATE
# 12 CARDINAL
# 13 CARDINAL
# 14 CARDINAL
# 15 CARDINAL
# 16 CARDINAL
# LONDON GPE
# Reuters ORG
# Bitcoin GPE
# Wednesday DATE
# 17 CARDINAL
# Reuters ORG
# 18 CARDINAL
# 19 CARDINAL
# The Securities and Exchange Commission ORG
# 1 CARDINAL
# Bitcoin GPE
# 2 CARDINAL
# first ORDINAL
# 3 CARDINAL
# 4 CARDINAL
# 5 CARDINAL
# 6 CARDINAL
# Reuters ORG
# 7 CARDINAL
# Reuters ORG
# 8 CARDINAL
# Reuters ORG
# 9 CARDINAL
# Bitcoin GPE
# Monday DATE
# 10 CARDINAL
# Vitalik Buterin.\r\n14 PERSON
# 1 CARDINAL
# 11 CARDINAL
# 2020 DATE
# 12 CARDINAL
# 13 CARDINAL
# 14 CARDINAL
# 15 CARDINAL
# 16 CARDINAL
# LONDON GPE
# Reuters ORG
# Bitcoin GPE
# Wednesday DATE
# 17 CARDINAL
# Reuters ORG
# 18 CARDINAL
# 19 CARDINAL
# The Securities and Exchange Commission ORG
# 1 CARDINAL
# Bitcoin GPE
# 2 CARDINAL
# first ORDINAL
# 3 CARDINAL
# 4 CARDINAL
# 5 CARDINAL
# 6 CARDINAL
# Reuters ORG
# 7 CARDINAL
# Reuters ORG
# 8 CARDINAL
# Reuters ORG
# 9 CARDINAL
# Bitcoin GPE
# Monday DATE
# 10 CARDINAL
# Vitalik Buterin.\r\n14 PERSON
# 1 CARDINAL
# 11 CARDINAL
# 2020 DATE
# 12 CARDINAL
# 13 CARDINAL
# 14 CARDINAL
# 15 CARDINAL
# 16 CARDINAL
# LONDON GPE
# Reuters ORG
# Bitcoin GPE
# Wednesday DATE
# 17 CARDINAL
# Reuters ORG
# 18 CARDINAL
# 19 CARDINAL
# The Securities and Exchange Commission ORG
# 1 CARDINAL
# Bitcoin GPE
# 2 CARDINAL
# first ORDINAL
# 3 CARDINAL
# 4 CARDINAL
# 5 CARDINAL
# 6 CARDINAL
# Reuters ORG
# 7 CARDINAL
# Reuters ORG
# 8 CARDINAL
# Reuters ORG
# 9 CARDINAL
# Bitcoin GPE
# Monday DATE
# 10 CARDINAL
# Vitalik Buterin.\r\n14 PERSON
# 1 CARDINAL
# 11 CARDINAL
# 2020 DATE
# 12 CARDINAL
# 13 CARDINAL
# 14 CARDINAL
# 15 CARDINAL
# 16 CARDINAL
# LONDON GPE
# Reuters ORG
# Bitcoin GPE
# Wednesday DATE
# 17 CARDINAL
# Reuters ORG
# 18 CARDINAL
# 19 CARDINAL
# The Securities and Exchange Commission ORG
# 1 CARDINAL
# Bitcoin GPE
# 2 CARDINAL
# first ORDINAL
# 3 CARDINAL
# 4 CARDINAL
# 5 CARDINAL
# 6 CARDINAL
# Reuters ORG
# 7 CARDINAL
# Reuters ORG
# 8 CARDINAL
# Reuters ORG
# 9 CARDINAL
# Bitcoin GPE
# Monday DATE
# 10 CARDINAL
# Vitalik Buterin.\r\n14 PERSON
# 1 CARDINAL
# 11 CARDINAL
# 2020 DATE
# 12 CARDINAL
# 13 CARDINAL
# 14 CARDINAL
# 15 CARDINAL
# 16 CARDINAL
# LONDON GPE
# Reuters ORG
# Bitcoin GPE
# Wednesday DATE
# 17 CARDINAL
# Reuters ORG
# 18 CARDINAL
# 19 CARDINAL
# The Securities and Exchange Commission ORG
# 1 CARDINAL
# Bitcoin GPE
# 2 CARDINAL
# first ORDINAL
# 3 CARDINAL
# 4 CARDINAL
# 5 CARDINAL
# 6 CARDINAL
# Reuters ORG
# 7 CARDINAL
# Reuters ORG
# 8 CARDINAL
# Reuters ORG
# 9 CARDINAL
# Bitcoin GPE
# Monday DATE
# 10 CARDINAL
# Vitalik Buterin.\r\n14 PERSON
# 1 CARDINAL
# 11 CARDINAL
# 2020 DATE
# 12 CARDINAL
# 13 CARDINAL
# 14 CARDINAL
# 15 CARDINAL
# 16 CARDINAL
# LONDON GPE
# Reuters ORG
# Bitcoin GPE
# Wednesday DATE
# 17 CARDINAL
# Reuters ORG
# 18 CARDINAL
# 19 CARDINAL
# The Securities and Exchange Commission ORG
# 1 CARDINAL
# Bitcoin GPE
# 2 CARDINAL
# first ORDINAL
# 3 CARDINAL
# 4 CARDINAL
# 5 CARDINAL
# 6 CARDINAL
# Reuters ORG
# 7 CARDINAL
# Reuters ORG
# 8 CARDINAL
# Reuters ORG
# 9 CARDINAL
# Bitcoin GPE
# Monday DATE
# 10 CARDINAL
# Vitalik Buterin.\r\n14 PERSON
# 1 CARDINAL
# 11 CARDINAL
# 2020 DATE
# 12 CARDINAL
# 13 CARDINAL
# 14 CARDINAL
# 15 CARDINAL
# 16 CARDINAL
# LONDON GPE
# Reuters ORG
# Bitcoin GPE
# Wednesday DATE
# 17 CARDINAL
# Reuters ORG
# 18 CARDINAL
# 19 CARDINAL
# The Securities and Exchange Commission ORG
# 1 CARDINAL
# Bitcoin GPE
# 2 CARDINAL
# first ORDINAL
# 3 CARDINAL
# 4 CARDINAL
# 5 CARDINAL
# 6 CARDINAL
# Reuters ORG
# 7 CARDINAL
# Reuters ORG
# 8 CARDINAL
# Reuters ORG
# 9 CARDINAL
# Bitcoin GPE
# Monday DATE
# 10 CARDINAL
# Vitalik Buterin.\r\n14 PERSON
# 1 CARDINAL
# 11 CARDINAL
# 2020 DATE
# 12 CARDINAL
# 13 CARDINAL
# 14 CARDINAL
# 15 CARDINAL
# 16 CARDINAL
# LONDON GPE
# Reuters ORG
# Bitcoin GPE
# Wednesday DATE
# 17 CARDINAL
# Reuters ORG
# 18 CARDINAL
# 19 CARDINAL
# The Securities and Exchange Commission ORG
# 1 CARDINAL
# Bitcoin GPE
# 2 CARDINAL
# first ORDINAL
# 3 CARDINAL
# 4 CARDINAL
# 5 CARDINAL
# 6 CARDINAL
# Reuters ORG
# 7 CARDINAL
# Reuters ORG
# 8 CARDINAL
# Reuters ORG
# 9 CARDINAL
# Bitcoin GPE
# Monday DATE
# 10 CARDINAL
# Vitalik Buterin.\r\n14 PERSON
# 1 CARDINAL
# 11 CARDINAL
# 2020 DATE
# 12 CARDINAL
# 13 CARDINAL
# 14 CARDINAL
# 15 CARDINAL
# 16 CARDINAL
# LONDON GPE
# Reuters ORG
# Bitcoin GPE
# Wednesday DATE
# 17 CARDINAL
# Reuters ORG
# 18 CARDINAL
# 19 CARDINAL
# The Securities and Exchange Commission ORG
# 1 CARDINAL
# Bitcoin GPE
# 2 CARDINAL
# first ORDINAL
# 3 CARDINAL
# 4 CARDINAL
# 5 CARDINAL
# 6 CARDINAL
# Reuters ORG
# 7 CARDINAL
# Reuters ORG
# 8 CARDINAL
# Reuters ORG
# 9 CARDINAL
# Bitcoin GPE
# Monday DATE
# 10 CARDINAL
# Vitalik Buterin.\r\n14 PERSON
# 1 CARDINAL
# 11 CARDINAL
# 2020 DATE
# 12 CARDINAL
# 13 CARDINAL
# 14 CARDINAL
# 15 CARDINAL
# 16 CARDINAL
# LONDON GPE
# Reuters ORG
# Bitcoin GPE
# Wednesday DATE
# 17 CARDINAL
# Reuters ORG
# 18 CARDINAL
# 19 CARDINAL
# The Securities and Exchange Commission ORG
# 1 CARDINAL
# Bitcoin GPE
# 2 CARDINAL
# first ORDINAL
# 3 CARDINAL
# 4 CARDINAL
# 5 CARDINAL
# 6 CARDINAL
# Reuters ORG
# 7 CARDINAL
# Reuters ORG
# 8 CARDINAL
# Reuters ORG
# 9 CARDINAL
# Bitcoin GPE
# Monday DATE
# 10 CARDINAL
# Vitalik Buterin.\r\n14 PERSON
# 1 CARDINAL
# 11 CARDINAL
# 2020 DATE
# 12 CARDINAL
# 13 CARDINAL
# 14 CARDINAL
# 15 CARDINAL
# 16 CARDINAL
# LONDON GPE
# Reuters ORG
# Bitcoin GPE
# Wednesday DATE
# 17 CARDINAL
# Reuters ORG
# 18 CARDINAL
# 19 CARDINAL
# The Securities and Exchange Commission ORG
# 1 CARDINAL
# Bitcoin GPE
# 2 CARDINAL
# first ORDINAL
# 3 CARDINAL
# 4 CARDINAL
# 5 CARDINAL
# 6 CARDINAL
# Reuters ORG
# 7 CARDINAL
# Reuters ORG
# 8 CARDINAL
# Reuters ORG
# 9 CARDINAL
# Bitcoin GPE
# Monday DATE
# 10 CARDINAL
# Vitalik Buterin.\r\n14 PERSON
# 1 CARDINAL
# 11 CARDINAL
# 2020 DATE
# 12 CARDINAL
# 13 CARDINAL
# 14 CARDINAL
# 15 CARDINAL
# 16 CARDINAL
# LONDON GPE
# Reuters ORG
# Bitcoin GPE
# Wednesday DATE
# 17 CARDINAL
# Reuters ORG
# 18 CARDINAL
# 19 CARDINAL
# The Securities and Exchange Commission ORG
# 1 CARDINAL
# Bitcoin GPE
# 2 CARDINAL
# first ORDINAL
# 3 CARDINAL
# 4 CARDINAL
# 5 CARDINAL
# 6 CARDINAL
# Reuters ORG
# 7 CARDINAL
# Reuters ORG
# 8 CARDINAL
# Reuters ORG
# 9 CARDINAL
# Bitcoin GPE
# Monday DATE
# 10 CARDINAL
# Vitalik Buterin.\r\n14 PERSON
# 1 CARDINAL
# 11 CARDINAL
# 2020 DATE
# 12 CARDINAL
# 13 CARDINAL
# 14 CARDINAL
# 15 CARDINAL
# 16 CARDINAL
# LONDON GPE
# Reuters ORG
# Bitcoin GPE
# Wednesday DATE
# 17 CARDINAL
# Reuters ORG
# 18 CARDINAL
# 19 CARDINAL
# The Securities and Exchange Commission ORG
# 1 CARDINAL
# Bitcoin GPE
# 2 CARDINAL
# first ORDINAL
# 3 CARDINAL
# 4 CARDINAL
# 5 CARDINAL
# 6 CARDINAL
# Reuters ORG
# 7 CARDINAL
# Reuters ORG
# 8 CARDINAL
# Reuters ORG
# 9 CARDINAL
# Bitcoin GPE
# Monday DATE
# 10 CARDINAL
# Vitalik Buterin.\r\n14 PERSON
# 1 CARDINAL
# 11 CARDINAL
# 2020 DATE
# 12 CARDINAL
# 13 CARDINAL
# 14 CARDINAL
# 15 CARDINAL
# 16 CARDINAL
# LONDON GPE
# Reuters ORG
# Bitcoin GPE
# Wednesday DATE
# 17 CARDINAL
# Reuters ORG
# 18 CARDINAL
# 19 CARDINAL
# The Securities and Exchange Commission ORG
# 1 CARDINAL
# Bitcoin GPE
# 2 CARDINAL
# first ORDINAL
# 3 CARDINAL
# 4 CARDINAL
# 5 CARDINAL
# 6 CARDINAL
# Reuters ORG
# 7 CARDINAL
# Reuters ORG
# 8 CARDINAL
# Reuters ORG
# 9 CARDINAL
# Bitcoin GPE
# Monday DATE
# 10 CARDINAL
# Vitalik Buterin.\r\n14 PERSON
# 1 CARDINAL
# 11 CARDINAL
# 2020 DATE
# 12 CARDINAL
# 13 CARDINAL
# 14 CARDINAL
# 15 CARDINAL
# 16 CARDINAL
# LONDON GPE
# Reuters ORG
# Bitcoin GPE
# Wednesday DATE
# 17 CARDINAL
# Reuters ORG
# 18 CARDINAL
# 19 CARDINAL
# The Securities and Exchange Commission ORG
# 1 CARDINAL
# Bitcoin GPE
# 2 CARDINAL
# first ORDINAL
# 3 CARDINAL
# 4 CARDINAL
# 5 CARDINAL
# 6 CARDINAL
# Reuters ORG
# 7 CARDINAL
# Reuters ORG
# 8 CARDINAL
# Reuters ORG
# 9 CARDINAL
# Bitcoin GPE
# Monday DATE
# 10 CARDINAL
# Vitalik Buterin.\r\n14 PERSON
# 1 CARDINAL
# 11 CARDINAL
# 2020 DATE
# 12 CARDINAL
# 13 CARDINAL
# 14 CARDINAL
# 15 CARDINAL
# 16 CARDINAL
# LONDON GPE
# Reuters ORG
# Bitcoin GPE
# Wednesday DATE
# 17 CARDINAL
# Reuters ORG
# 18 CARDINAL
# 19 CARDINAL
# The Securities and Exchange Commission ORG
# 1 CARDINAL
# Bitcoin GPE
# 2 CARDINAL
# first ORDINAL
# 3 CARDINAL
# 4 CARDINAL
# 5 CARDINAL
# 6 CARDINAL
# Reuters ORG
# 7 CARDINAL
# Reuters ORG
# 8 CARDINAL
# Reuters ORG
# 9 CARDINAL
# Bitcoin GPE
# Monday DATE
# 10 CARDINAL
# Vitalik Buterin.\r\n14 PERSON
# 1 CARDINAL
# 11 CARDINAL
# 2020 DATE
# 12 CARDINAL
# 13 CARDINAL
# 14 CARDINAL
# 15 CARDINAL
# 16 CARDINAL
# LONDON GPE
# Reuters ORG
# Bitcoin GPE
# Wednesday DATE
# 17 CARDINAL
# Reuters ORG
# 18 CARDINAL
# 19 CARDINAL
# The Securities and Exchange Commission ORG
# 1 CARDINAL
# Bitcoin GPE
# 2 CARDINAL
# first ORDINAL
# 3 CARDINAL
# 4 CARDINAL
# 5 CARDINAL
# 6 CARDINAL
# Reuters ORG
# 7 CARDINAL
# Reuters ORG
# 8 CARDINAL
# Reuters ORG
# 9 CARDINAL
# Bitcoin GPE
# Monday DATE
# 10 CARDINAL
# Vitalik Buterin.\r\n14 PERSON
# 1 CARDINAL
# 11 CARDINAL
# 2020 DATE
# 12 CARDINAL
# 13 CARDINAL
# 14 CARDINAL
# 15 CARDINAL
# 16 CARDINAL
# LONDON GPE
# Reuters ORG
# Bitcoin GPE
# Wednesday DATE
# 17 CARDINAL
# Reuters ORG
# 18 CARDINAL
# 19 CARDINAL
# The Securities and Exchange Commission ORG
# 1 CARDINAL
# Bitcoin GPE
# 2 CARDINAL
# first ORDINAL
# 3 CARDINAL
# 4 CARDINAL
# 5 CARDINAL
# 6 CARDINAL
# Reuters ORG
# 7 CARDINAL
# Reuters ORG
# 8 CARDINAL
# Reuters ORG
# 9 CARDINAL
# Bitcoin GPE
# Monday DATE
# 10 CARDINAL
# Vitalik Buterin.\r\n14 PERSON
# 1 CARDINAL
# 11 CARDINAL
# 2020 DATE
# 12 CARDINAL
# 13 CARDINAL
# 14 CARDINAL
# 15 CARDINAL
# 16 CARDINAL
# LONDON GPE
# Reuters ORG
# Bitcoin GPE
# Wednesday DATE
# 17 CARDINAL
# Reuters ORG
# 18 CARDINAL
# 19 CARDINAL
# The Securities and Exchange Commission ORG
# 1 CARDINAL
# Bitcoin GPE
# 2 CARDINAL
# first ORDINAL
# 3 CARDINAL
# 4 CARDINAL
# 5 CARDINAL
# 6 CARDINAL
# Reuters ORG
# 7 CARDINAL
# Reuters ORG
# 8 CARDINAL
# Reuters ORG
# 9 CARDINAL
# Bitcoin GPE
# Monday DATE
# 10 CARDINAL
# Vitalik Buterin.\r\n14 PERSON
# 1 CARDINAL
# 11 CARDINAL
# 2020 DATE
# 12 CARDINAL
# 13 CARDINAL
# 14 CARDINAL
# 15 CARDINAL
# 16 CARDINAL
# LONDON GPE
# Reuters ORG
# Bitcoin GPE
# Wednesday DATE
# 17 CARDINAL
# Reuters ORG
# 18 CARDINAL
# 19 CARDINAL

# %% [markdown]
# ---
